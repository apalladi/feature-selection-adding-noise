# %%
import numpy as np

# %%
from src.data import create_regression_data

X, y = create_regression_data()

X.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  0.129755 -0.567948  0.706519  0.892852  0.660359  0.384878 -0.878018
# 1  0.183935  0.562989  0.418338  1.546420  1.514245  0.460616  0.652313
# 2  0.061848  1.921317 -0.118390 -0.578357 -1.109966  1.576929  0.156121
# 3  1.787556  0.605088 -1.702973  0.042445  0.245516 -0.974867  1.990158
# 4  0.169776  0.907741 -0.090658 -0.342734 -0.268763 -0.371068  0.918470
#
#       col_7     col_8     col_9  ...   col_290   col_291   col_292   col_293  \
# 0  0.587905 -0.876707 -0.571186  ...  1.153132  0.186501 -1.467343 -1.082474
# 1  0.505121 -0.135665  0.644324  ... -0.258581 -0.569830  1.529708 -0.357404
# 2  0.925265 -1.440220  0.242119  ... -0.284009  0.016948 -0.767781 -0.232449
# 3  0.241210  0.271530  0.029864  ... -0.066860 -0.244598  0.071732  0.834652
# 4  0.333345  0.799839  0.250106  ...  1.350097  0.031552  0.568855  0.039821
#
#     col_294   col_295   col_296   col_297   col_298   col_299
# ...

# %%
from src.ml import get_relevant_features, scan_features
from sklearn.linear_model import Lasso

X_reduced = get_relevant_features(X, y, 
                                  model=Lasso(), 
                                  epochs=100, 
                                  patience=10, 
                                  filename_output='results/reduced_dataset.csv')
# Out:
# Fitting the model with 301 features
# Train score 0.9307
# Test score 0.8343
# Selected 300 features out of 301
# The feature selection did not improve in the last 1 epochs
# Fitting the model with 301 features
# Train score 0.9294
# Test score 0.8477
# Selected 114 features out of 301
# Fitting the model with 115 features
# Train score 0.9195
# Test score 0.8671
# Selected 81 features out of 115
# Fitting the model with 82 features
# Train score 0.9115
# Test score 0.9036
# Selected 74 features out of 82
# Fitting the model with 75 features
# Train score 0.9156
# Test score 0.884
# Selected 35 features out of 75
# Fitting the model with 36 features
# Train score 0.901
# Test score 0.9059
# Selected 35 features out of 36
# The feature selection did not improve in the last 1 epochs
# Fitting the model with 36 features
# Train score 0.9039
# Test score 0.8942
# Selected 35 features out of 36
# The feature selection did not improve in the last 2 epochs
# ...

# %%
X_reduced.head()
# Out:
#     col_210    col_47   col_150    col_39   col_151   col_115   col_184  \
# 0 -0.089868  0.114691 -1.767657  0.671466 -0.811459 -0.211540 -1.242322
# 1  0.438617 -0.497921  0.450107 -0.679240 -0.336694 -0.064378 -0.755123
# 2 -1.159601  0.637081  0.263410 -1.064539 -0.390603 -0.266203 -0.064790
# 3  0.012683 -0.921343  0.583995 -1.003227 -0.320328 -0.150921  0.961633
# 4 -2.075502  1.266558 -0.271106 -0.548530 -0.836423 -0.410451 -1.623004
#
#     col_162    col_88   col_159  ...    col_29   col_266    col_58    col_96  \
# 0  2.598037 -0.492159 -0.841387  ... -0.648870 -1.840890  1.236696 -2.533453
# 1 -2.014982 -0.612354 -1.687833  ...  0.198120 -2.773993 -1.022197 -1.177753
# 2 -0.053107 -0.362443  0.223787  ... -0.113094 -0.860390 -0.787065  0.947543
# 3 -0.251490  0.011908 -0.255779  ... -2.595097 -0.486850 -0.426385  1.757797
# 4 -0.656845  0.091682 -0.373852  ... -1.431535 -0.409879 -0.037009  0.754480
#
#     col_175   col_132    col_76   col_269   col_297   col_206
# ...
