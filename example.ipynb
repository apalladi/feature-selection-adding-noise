# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import toy regression data

# %%
X = pd.read_csv('data/toy-regression-features.csv')
y = pd.read_csv('data/toy-regression-labels.csv')

# %%
X.head()
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  0.537070 -1.102140  1.614065  0.446704  2.150072  0.022795 -0.062325
# 1 -0.291104  0.870662  0.989858  0.340181  0.462467 -0.582148  1.888760
# 2 -0.623914  0.645679 -0.603598 -0.382241 -1.038855  1.036846 -0.411746
# 3 -0.007280 -1.159284  1.205723 -0.869215 -0.571466  0.540196  0.656639
# 4  0.578238 -0.756635 -0.768636  1.339886  0.612525 -0.431343 -0.058266
#
#       col_7     col_8     col_9  ...   col_290   col_291   col_292   col_293  \
# 0  0.842601  1.337646  0.423004  ... -0.923334 -0.481815  1.203645 -1.458585
# 1  1.326881 -1.654321 -0.130696  ...  1.429273  0.845691 -1.089257 -0.918355
# 2  0.309138  0.377860  1.115033  ... -0.853996 -1.977211 -0.360070  0.457125
# 3  0.041661  0.244310 -0.860549  ...  0.646255 -0.762227 -0.940969 -0.889827
# 4  0.975151 -1.992118  0.179272  ...  0.263658  0.837735  0.724682 -2.493489
#
#     col_294   col_295   col_296   col_297   col_298   col_299
# 0 -0.382055  0.778446  1.281670  0.083526  0.690047  0.117204
# 1  0.394018  2.608926 -1.485463 -0.907812 -0.173660  0.920506
# 2 -1.372804  0.320784 -0.961563 -0.203412  0.920264  0.799161
# 3 -0.534136 -0.649951 -0.387092 -1.089814  0.054935  0.955872
# 4 -2.108600 -1.646070 -0.674911 -0.344457 -0.771689 -0.691474
#
# [5 rows x 300 columns]

# %%
y.head()
# Out:
#        labels
# 0  219.664211
# 1   40.998126
# 2  109.423858
# 3 -280.667507
# 4  599.178538

# %% [markdown]
# ### Use the library to select only the relevant features

# %%
from src.ml import get_relevant_features, scan_features
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=1)

X_reduced = get_relevant_features(X, y, 
                                  model=lasso_model, 
                                  epochs=100, 
                                  patience=5, 
                                  filename_output='results/reduced_dataset.csv')
# Out:
# =====================EPOCH 1 =====================
# Fitting the model with 301 features
# Train score 0.9254
# Test score 0.857
# Selected 51 features out of 300
# =====================EPOCH 2 =====================
# Fitting the model with 52 features
# Train score 0.8986
# Test score 0.9146
# Selected 50 features out of 51
# =====================EPOCH 3 =====================
# Fitting the model with 51 features
# Train score 0.9037
# Test score 0.8945
# Selected 45 features out of 50
# =====================EPOCH 4 =====================
# Fitting the model with 46 features
# Train score 0.9015
# Test score 0.9038
# Selected 42 features out of 45
# =====================EPOCH 5 =====================
# Fitting the model with 43 features
# Train score 0.9022
# Test score 0.8944
# Selected 42 features out of 42
# The feature selection did not improve in the last 1 epochs
# =====================EPOCH 6 =====================
# Fitting the model with 43 features
# Train score 0.9067
# Test score 0.8734
# Selected 41 features out of 42
# =====================EPOCH 7 =====================
# Fitting the model with 42 features
# Train score 0.9013
# Test score 0.9036
# Selected 36 features out of 41
# =====================EPOCH 8 =====================
# Fitting the model with 37 features
# Train score 0.9018
# Test score 0.895
# Selected 36 features out of 36
# The feature selection did not improve in the last 1 epochs
# =====================EPOCH 9 =====================
# Fitting the model with 37 features
# Train score 0.9037
# Test score 0.8867
# Selected 36 features out of 36
# The feature selection did not improve in the last 2 epochs
# =====================EPOCH 10 =====================
# Fitting the model with 37 features
# Train score 0.9027
# Test score 0.893
# Selected 36 features out of 36
# The feature selection did not improve in the last 3 epochs
# =====================EPOCH 11 =====================
# Fitting the model with 37 features
# Train score 0.9046
# Test score 0.8824
# Selected 36 features out of 36
# The feature selection did not improve in the last 4 epochs
# =====================EPOCH 12 =====================
# Fitting the model with 37 features
# Train score 0.8993
# Test score 0.909
# Selected 34 features out of 36
# =====================EPOCH 13 =====================
# Fitting the model with 35 features
# Train score 0.9026
# Test score 0.8904
# Selected 29 features out of 34
# =====================EPOCH 14 =====================
# Fitting the model with 30 features
# Train score 0.9002
# Test score 0.8927
# Selected 29 features out of 29
# The feature selection did not improve in the last 1 epochs
# =====================EPOCH 15 =====================
# Fitting the model with 30 features
# Train score 0.8952
# Test score 0.91
# Selected 29 features out of 29
# The feature selection did not improve in the last 2 epochs
# =====================EPOCH 16 =====================
# Fitting the model with 30 features
# Train score 0.8992
# Test score 0.8969
# Selected 29 features out of 29
# The feature selection did not improve in the last 3 epochs
# =====================EPOCH 17 =====================
# Fitting the model with 30 features
# Train score 0.8994
# Test score 0.8957
# Selected 27 features out of 29
# =====================EPOCH 18 =====================
# Fitting the model with 28 features
# Train score 0.9054
# Test score 0.8623
# Selected 27 features out of 27
# The feature selection did not improve in the last 1 epochs
# =====================EPOCH 19 =====================
# Fitting the model with 28 features
# Train score 0.8957
# Test score 0.905
# Selected 27 features out of 27
# The feature selection did not improve in the last 2 epochs
# =====================EPOCH 20 =====================
# Fitting the model with 28 features
# Train score 0.898
# Test score 0.8995
# Selected 27 features out of 27
# The feature selection did not improve in the last 3 epochs
# =====================EPOCH 21 =====================
# Fitting the model with 28 features
# Train score 0.9054
# Test score 0.8611
# Selected 26 features out of 27
# =====================EPOCH 22 =====================
# Fitting the model with 27 features
# Train score 0.9059
# Test score 0.8602
# Selected 26 features out of 26
# The feature selection did not improve in the last 1 epochs
# =====================EPOCH 23 =====================
# Fitting the model with 27 features
# Train score 0.8979
# Test score 0.898
# Selected 26 features out of 26
# The feature selection did not improve in the last 2 epochs
# =====================EPOCH 24 =====================
# Fitting the model with 27 features
# Train score 0.8999
# Test score 0.8914
# Selected 26 features out of 26
# The feature selection did not improve in the last 3 epochs
# =====================EPOCH 25 =====================
# Fitting the model with 27 features
# Train score 0.8968
# Test score 0.9011
# Selected 26 features out of 26
# The feature selection did not improve in the last 4 epochs
# =====================EPOCH 26 =====================
# Fitting the model with 27 features
# Train score 0.9005
# Test score 0.886
# Selected 26 features out of 26
# The feature selection did not improve in the last 5 epochs

# %% [markdown]
# ### Inspect the new (reduced) dataset

# %%
X_reduced.head()
# Out:
#     col_277   col_168    col_88   col_270   col_283     col_8   col_258  \
# 0 -0.003618 -0.003067 -1.019952  0.220574 -2.092326  1.337646  1.673497
# 1  0.259951  0.030676  0.920548 -0.041250  0.685426 -1.654321 -0.051170
# 2 -1.351804  0.459295 -3.277806  0.758731  0.933398  0.377860  0.971993
# 3 -0.413398  0.002783 -0.936796 -0.781265  1.153329  0.244310  0.744198
# 4  3.081069  0.054107  0.842412  0.513912 -0.148948 -1.992118  0.093666
#
#     col_187    col_76   col_171  ...   col_174    col_24    col_25   col_250  \
# 0  0.236082  0.656732 -0.878309  ...  0.577020 -0.309741  1.178854  1.053236
# 1  0.853362 -0.367285 -0.343505  ...  0.653817  0.830601 -0.570561 -1.545429
# 2 -0.739010  0.200066 -0.076279  ... -0.260010 -1.145208  1.957113  2.176639
# 3  1.123666  0.328173 -0.379941  ... -0.077514 -1.016165  0.245085 -2.033497
# 4  2.831712  1.261611  0.741283  ... -0.676896  2.785978 -0.719393  0.351711
#
#     col_274    col_55    col_49    col_45   col_256    col_31
# 0  0.692207  0.800531  1.635062  1.498433 -1.133235  1.583720
# 1 -0.808267 -0.017992  0.132372 -1.335906  0.059484  0.502085
# 2 -1.399284  0.742541 -0.715981 -0.852144  0.225024  2.300833
# 3  0.221333 -0.630077  0.664429  0.389595  1.065514  0.198592
# 4  0.234328 -1.068996 -0.314443 -0.178059  0.360939 -0.831037
#
# [5 rows x 26 columns]
